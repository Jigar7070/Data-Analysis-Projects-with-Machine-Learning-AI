# %% [markdown]
# Predicting the future sales of a product helps a business manage the manufacturing and advertising cost of the product. There are many more benefits of predicting the future sales of a product

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

data = pd.read_csv("https://raw.githubusercontent.com/amankharwal/Website-data/master/advertising.csv")
print(data.head())
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
print(data.isnull().sum())
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# Now let’s visualize the relationship between the amount spent on advertising on TV and units sold

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.regplot(data=data, x="Sales", y="TV", scatter_kws={"s": 100}, line_kws={"color": "red"})
plt.title("Sales vs TV Advertisement Spend")
plt.xlabel("Sales")
plt.ylabel("TV Ad Spend")
plt.show()

# %% [markdown]
# Now let’s visualize the relationship between the amount spent on advertising on newspapers and units sold

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter plot with regression line
plt.figure(figsize=(10, 6))
sns.regplot(data=data, x="Sales", y="Newspaper", scatter_kws={"s": 100}, line_kws={"color": "red"})
plt.title("Sales vs Newspaper Advertisement Spend")
plt.xlabel("Sales")
plt.ylabel("Newspaper Ad Spend")
plt.show()

# %% [markdown]
# Now let’s visualize the relationship between the amount spent on advertising on radio and units sold

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter plot with regression line
plt.figure(figsize=(10, 6))
sns.regplot(data=data, x="Sales", y="Radio", scatter_kws={"s": 100}, line_kws={"color": "red"})
plt.title("Sales vs Radio Advertisement Spend")
plt.xlabel("Sales")
plt.ylabel("Radio Ad Spend")
plt.show()

# %% [markdown]
# Out of all the amount spent on advertising on various platforms, I can see that the amount spent on advertising the product on TV results in more sales of the product

# %% [markdown]
# Now let’s have a look at the correlation of all the columns with the sales column

# %%
correlation = data.corr()
print(correlation["Sales"].sort_values(ascending=False))
# Out:
# Sales        1.000000
# TV           0.901208
# Radio        0.349631
# Newspaper    0.157960
# Name: Sales, dtype: float64

# %% [markdown]
# ### Future Sales Prediction Model

# %% [markdown]
# I will train a machine learning model to predict the future sales of a product. But before I train the model, let’s split the data into training and test sets

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# Correcting the drop() function
x = np.array(data.drop(["Sales"], axis=1))  # Explicitly specify axis=1 for column drop
y = np.array(data["Sales"])

# Splitting data
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(xtrain, ytrain)
print(model.score(xtest, ytest))
# Out:
# 0.9059011844150826

# %%
features = np.array([[230.1, 37.8, 69.2]])
print(model.predict(features))
# Out:
# [21.37254028]
